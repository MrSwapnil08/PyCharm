# %%
import pandas as pd

# %%
df = pd.read_csv("F:\Avd\Python\datasets\datasets\datasets\empdata1.csv")

# %%
df
# Out:
#    empid           ename       sal       doj
# 0   1001      Ganesh Rao  10000.00  10-10-00
# 1   1002      Anil Kumar  23000.50  03-03-02
# 2   1003             NaN  18000.33  03-03-02
# 3   1004    Hema Chandra       NaN       NaN
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 5   1006       Anant Nag   9999.99  09-09-99

# %%
df1 = df.fillna(0)
df1
# Out:
#    empid           ename       sal       doj
# 0   1001      Ganesh Rao  10000.00  10-10-00
# 1   1002      Anil Kumar  23000.50  03-03-02
# 2   1003               0  18000.33  03-03-02
# 3   1004    Hema Chandra      0.00         0
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 5   1006       Anant Nag   9999.99  09-09-99

# %%
avg = df.sal.mean()
avg
# Out:
# 14600.314000000002

# %%
df1 = df.fillna({'ename':'No name','sal':avg, 'doj':'1-1-90'})

# %%
df1
# Out:
#    empid           ename        sal       doj
# 0   1001      Ganesh Rao  10000.000  10-10-00
# 1   1002      Anil Kumar  23000.500  03-03-02
# 2   1003         No name  18000.330  03-03-02
# 3   1004    Hema Chandra  14600.314    1-1-90
# 4   1005  Laxmi Prasanna  12000.750  10-08-00
# 5   1006       Anant Nag   9999.990  09-09-99

# %%
df1 =df.dropna()
df1
# Out:
#    empid           ename       sal       doj
# 0   1001      Ganesh Rao  10000.00  10-10-00
# 1   1002      Anil Kumar  23000.50  03-03-02
# 4   1005  Laxmi Prasanna  12000.75  10-08-00
# 5   1006       Anant Nag   9999.99  09-09-99

# %%
df = pd.read_csv("F:\Avd\Python\datasets\datasets\datasets\empdata.csv")

# %%
df
# Out:
#    empid           ename       sal         doj
# 0   1001      Ganesh Rao  10000.00  10-10-2000
# 1   1002      Anil Kumar  23000.50    3-3-2002
# 2   1003    Gaurav Gupta  18000.33    3-3-2002
# 3   1004    Hema Chandra  16500.50    3-3-2002
# 4   1005  Laxmi Prasanna  12000.75   10-8-2000
# 5   1006       Anant Nag   9999.99    9-9-1999

# %%
#sort the date of join as it is saved as string. convert it in date.

# %%
df = pd.read_csv("F:\Avd\Python\datasets\datasets\datasets\empdata.csv", parse_dates=['doj'])

# %%
df
# Out:
#    empid           ename       sal        doj
# 0   1001      Ganesh Rao  10000.00 2000-10-10
# 1   1002      Anil Kumar  23000.50 2002-03-03
# 2   1003    Gaurav Gupta  18000.33 2002-03-03
# 3   1004    Hema Chandra  16500.50 2002-03-03
# 4   1005  Laxmi Prasanna  12000.75 2000-10-08
# 5   1006       Anant Nag   9999.99 1999-09-09

# %%
df1 = df.sort_values('doj')
df1
# Out:
#    empid           ename       sal        doj
# 5   1006       Anant Nag   9999.99 1999-09-09
# 4   1005  Laxmi Prasanna  12000.75 2000-10-08
# 0   1001      Ganesh Rao  10000.00 2000-10-10
# 1   1002      Anil Kumar  23000.50 2002-03-03
# 2   1003    Gaurav Gupta  18000.33 2002-03-03
# 3   1004    Hema Chandra  16500.50 2002-03-03

# %%
df1 = df.sort_values('doj', ascending= False)

# %%
df1
# Out:
#    empid           ename       sal        doj
# 1   1002      Anil Kumar  23000.50 2002-03-03
# 2   1003    Gaurav Gupta  18000.33 2002-03-03
# 3   1004    Hema Chandra  16500.50 2002-03-03
# 0   1001      Ganesh Rao  10000.00 2000-10-10
# 4   1005  Laxmi Prasanna  12000.75 2000-10-08
# 5   1006       Anant Nag   9999.99 1999-09-09

# %%
#doj is same salary is sorted in ascending order

# %%
df1 = df.sort_values(by = ['doj','sal'], ascending= [False,True])
df1
# Out:
#    empid           ename       sal        doj
# 3   1004    Hema Chandra  16500.50 2002-03-03
# 2   1003    Gaurav Gupta  18000.33 2002-03-03
# 1   1002      Anil Kumar  23000.50 2002-03-03
# 0   1001      Ganesh Rao  10000.00 2000-10-10
# 4   1005  Laxmi Prasanna  12000.75 2000-10-08
# 5   1006       Anant Nag   9999.99 1999-09-09

# %%
df = pd.read_csv("F:/Avd/Python/datasets/datasets/datasets/nba.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['Name']
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 452       Trey Lyles
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# Name: Name, Length: 457, dtype: object

# %%
s1 = pd.Series(df['Name'])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series(df['Age'])
s2
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 4      29
#        ..
# 452    20
# 453    26
# 454    24
# 455    26
# 456    26
# Name: Age, Length: 457, dtype: int64

# %%
#creating data frame from series #axis means column vise concatination.
df = pd.concat([s1,s2],axis =1)   
df
# Out:
#               Name  Age
# 0    Avery Bradley   25
# 1      Jae Crowder   25
# 2     John Holland   27
# 3      R.J. Hunter   22
# 4    Jonas Jerebko   29
# ..             ...  ...
# 452     Trey Lyles   20
# 453   Shelvin Mack   26
# 454      Raul Neto   24
# 455   Tibor Pleiss   26
# 456    Jeff Withey   26
#
# [457 rows x 2 columns]

# %%
#change column names in df
df.columns = ['PlayerName','PlayerAge']
df
# Out:
#         PlayerName  PlayerAge
# 0    Avery Bradley         25
# 1      Jae Crowder         25
# 2     John Holland         27
# 3      R.J. Hunter         22
# 4    Jonas Jerebko         29
# ..             ...        ...
# 452     Trey Lyles         20
# 453   Shelvin Mack         26
# 454      Raul Neto         24
# 455   Tibor Pleiss         26
# 456    Jeff Withey         26
#
# [457 rows x 2 columns]

# %%
mydict = {'player_name':s1, 'player_age' : s2}
df1 = pd.DataFrame(mydict)
df1
# Out:
#        player_name  player_age
# 0    Avery Bradley          25
# 1      Jae Crowder          25
# 2     John Holland          27
# 3      R.J. Hunter          22
# 4    Jonas Jerebko          29
# ..             ...         ...
# 452     Trey Lyles          20
# 453   Shelvin Mack          26
# 454      Raul Neto          24
# 455   Tibor Pleiss          26
# 456    Jeff Withey          26
#
# [457 rows x 2 columns]

# %%
#convert into array 
s2.values
# Out:
# array([25, 25, 27, 22, 29, 29, 21, 25, 22, 22, 24, 27, 27, 20, 26, 27, 24,
#        28, 21, 32, 22, 26, 23, 28, 21, 26, 25, 26, 28, 27, 30, 33, 23, 32,
#        34, 25, 24, 23, 28, 26, 20, 26, 28, 32, 25, 23, 37, 25, 25, 22, 22,
#        22, 32, 24, 24, 22, 20, 27, 22, 25, 20, 23, 20, 29, 26, 29, 24, 30,
#        23, 27, 23, 25, 36, 29, 24, 24, 33, 24, 31, 25, 28, 26, 26, 32, 30,
#        20, 23, 30, 28, 26, 33, 27, 29, 36, 23, 29, 27, 28, 27, 29, 31, 38,
#        39, 31, 23, 25, 31, 24, 23, 37, 24, 29, 33, 25, 23, 21, 20, 27, 29,
#        36, 31, 26, 19, 28, 33, 21, 25, 24, 22, 27, 25, 32, 30, 31, 22, 23,
#        25, 27, 30, 36, 27, 22, 28, 25, 25, 24, 29, 27, 23, 24, 30, 25, 31,
#        26, 35, 23, 35, 30, 27, 24, 25, 27, 31, 21, 27, 24, 25, 33, 24, 31,
#        35, 35, 35, 31, 27, 25, 29, 25, 30, 25, 33, 33, 29, 36, 25, 25, 23,
#        23, 22, 23, 23, 26, 20, 28, 26, 31, 27, 24, 30, 26, 30, 28, 25, 28,
# ...

# %%
#convert array into series 
import numpy as np 
arr = np.array([10, 20, 33, 43, 90])
arr
# Out:
# array([10, 20, 33, 43, 90])

# %%
ser = pd.Series(arr)
ser
# Out:
# 0    10
# 1    20
# 2    33
# 3    43
# 4    90
# dtype: int32

# %%
#create a series from a dictionary 
mydict = {'name': ['a','b', 'c', 'd'],
         'age':[24, 35, 44, 50],
          'design':['Dev', 'dev','HR','PM']
         }

# %%
ser = pd.Series(mydict)
ser
# Out:
# name            [a, b, c, d]
# age         [24, 35, 44, 50]
# design    [Dev, dev, HR, PM]
# dtype: object

# %%
ser['design'][2]
# Out:
# 'HR'

# %%
df = pd.read_csv("F:\Avd\Python\datasets\datasets\datasets\empdata.csv")

# %%
df
# Out:
#    empid           ename       sal         doj
# 0   1001      Ganesh Rao  10000.00  10-10-2000
# 1   1002      Anil Kumar  23000.50    3-3-2002
# 2   1003    Gaurav Gupta  18000.33    3-3-2002
# 3   1004    Hema Chandra  16500.50    3-3-2002
# 4   1005  Laxmi Prasanna  12000.75   10-8-2000
# 5   1006       Anant Nag   9999.99    9-9-1999

# %%
#Adding a row in df
df.loc[7]=['107', 'Laxmi Sundari', 45000.00, '1-1-2000']
df
# Out:
#   empid           ename       sal         doj
# 0  1001      Ganesh Rao  10000.00  10-10-2000
# 1  1002      Anil Kumar  23000.50    3-3-2002
# 2  1003    Gaurav Gupta  18000.33    3-3-2002
# 3  1004    Hema Chandra  16500.50    3-3-2002
# 4  1005  Laxmi Prasanna  12000.75   10-8-2000
# 5  1006       Anant Nag   9999.99    9-9-1999
# 7   107   Laxmi Sundari  45000.00    1-1-2000

# %%
#we wish to save the modified data into updated csv file.copy the path wehere you wish to save new file with new name. 
df.to_csv("F:/Avd/Python/datasets/datasets/datasets/newdata.csv")

# %%
#new excel file 
df.to_excel("F:/Avd/Python/datasets/datasets/datasets/newdata.xlsx")
